# %%
# !pip install tensorflow
# Out:
# Collecting tensorflow
#   Downloading tensorflow-2.15.0-cp310-cp310-win_amd64.whl (2.1 kB)
# Collecting tensorflow-intel==2.15.0
#   Downloading tensorflow_intel-2.15.0-cp310-cp310-win_amd64.whl (300.9 MB)
#      ---------------------------------------- 0.0/300.9 MB ? eta -:--:--
#      ---------------------------------------- 0.1/300.9 MB 2.6 MB/s eta 0:01:58
#      ---------------------------------------- 0.3/300.9 MB 4.3 MB/s eta 0:01:10
#      ---------------------------------------- 0.9/300.9 MB 8.3 MB/s eta 0:00:37
#      --------------------------------------- 2.0/300.9 MB 12.7 MB/s eta 0:00:24
#      --------------------------------------- 3.5/300.9 MB 18.6 MB/s eta 0:00:17
#       -------------------------------------- 5.6/300.9 MB 23.7 MB/s eta 0:00:13
#      - ------------------------------------- 7.8/300.9 MB 27.6 MB/s eta 0:00:11
#      - ------------------------------------- 9.4/300.9 MB 28.6 MB/s eta 0:00:11
#      - ------------------------------------ 10.7/300.9 MB 36.4 MB/s eta 0:00:08
#      - ------------------------------------ 12.2/300.9 MB 40.9 MB/s eta 0:00:08
#      - ------------------------------------ 13.9/300.9 MB 40.9 MB/s eta 0:00:08
#      -- ----------------------------------- 16.0/300.9 MB 43.5 MB/s eta 0:00:07
#      -- ----------------------------------- 17.4/300.9 MB 40.9 MB/s eta 0:00:07
#      -- ----------------------------------- 19.7/300.9 MB 40.9 MB/s eta 0:00:07
#      -- ----------------------------------- 20.5/300.9 MB 40.9 MB/s eta 0:00:07
#      -- ----------------------------------- 21.4/300.9 MB 38.5 MB/s eta 0:00:08
#      -- ----------------------------------- 22.5/300.9 MB 38.5 MB/s eta 0:00:08
#      -- ----------------------------------- 23.3/300.9 MB 34.4 MB/s eta 0:00:09
#      --- ---------------------------------- 24.5/300.9 MB 32.7 MB/s eta 0:00:09
#      --- ---------------------------------- 26.4/300.9 MB 31.2 MB/s eta 0:00:09
#      --- ---------------------------------- 28.2/300.9 MB 32.7 MB/s eta 0:00:09
#      --- ---------------------------------- 29.0/300.9 MB 29.7 MB/s eta 0:00:10
#      --- ---------------------------------- 30.4/300.9 MB 28.5 MB/s eta 0:00:10
#      ---- --------------------------------- 32.4/300.9 MB 34.4 MB/s eta 0:00:08
#      ---- --------------------------------- 33.3/300.9 MB 34.4 MB/s eta 0:00:08
#      ---- --------------------------------- 34.6/300.9 MB 34.6 MB/s eta 0:00:08
#      ---- --------------------------------- 36.2/300.9 MB 34.4 MB/s eta 0:00:08
#      ---- --------------------------------- 37.1/300.9 MB 32.7 MB/s eta 0:00:09
#      ---- --------------------------------- 38.5/300.9 MB 32.7 MB/s eta 0:00:09
#      ---- --------------------------------- 39.6/300.9 MB 32.7 MB/s eta 0:00:08
#      ----- -------------------------------- 42.4/300.9 MB 27.3 MB/s eta 0:00:10
#      ----- -------------------------------- 44.9/300.9 MB 28.4 MB/s eta 0:00:10
#      ----- -------------------------------- 46.4/300.9 MB 21.9 MB/s eta 0:00:12
#      ------ ------------------------------- 48.5/300.9 MB 24.2 MB/s eta 0:00:11
#      ------ ------------------------------- 49.9/300.9 MB 24.2 MB/s eta 0:00:11
#      ------ ------------------------------- 51.2/300.9 MB 26.2 MB/s eta 0:00:10
#      ------------------------ ------------ 200.2/300.9 MB 31.2 MB/s eta 0:00:04
#      ------------------------ ------------ 201.2/300.9 MB 31.2 MB/s eta 0:00:04
#      ------------------------ ------------ 202.2/300.9 MB 31.2 MB/s eta 0:00:04
#      ------------------------- ----------- 203.5/300.9 MB 28.5 MB/s eta 0:00:04
#      ------------------------- ----------- 204.7/300.9 MB 29.8 MB/s eta 0:00:04
#      ------------------------- ----------- 206.8/300.9 MB 31.2 MB/s eta 0:00:04
#      ------------------------- ----------- 207.7/300.9 MB 32.8 MB/s eta 0:00:03
#      ------------------------- ----------- 209.2/300.9 MB 32.8 MB/s eta 0:00:03
#      ------------------------- ----------- 211.2/300.9 MB 34.4 MB/s eta 0:00:03
#      -------------------------- ---------- 212.9/300.9 MB 38.5 MB/s eta 0:00:03
#      -------------------------- ---------- 214.5/300.9 MB 40.9 MB/s eta 0:00:03
#      -------------------------- ---------- 215.2/300.9 MB 36.4 MB/s eta 0:00:03
#      -------------------------- ---------- 216.5/300.9 MB 34.4 MB/s eta 0:00:03
#      -------------------------- ---------- 218.0/300.9 MB 36.4 MB/s eta 0:00:03
#      -------------------------- ---------- 218.9/300.9 MB 34.4 MB/s eta 0:00:03
#      --------------------------- --------- 220.0/300.9 MB 32.7 MB/s eta 0:00:03
#      --------------------------- --------- 221.2/300.9 MB 32.8 MB/s eta 0:00:03
#      --------------------------- --------- 222.5/300.9 MB 29.7 MB/s eta 0:00:03
#      --------------------------- --------- 223.7/300.9 MB 29.7 MB/s eta 0:00:03
#      --------------------------- --------- 225.6/300.9 MB 32.8 MB/s eta 0:00:03
#      --------------------------- --------- 226.0/300.9 MB 32.8 MB/s eta 0:00:03
#      --------------------------- --------- 227.3/300.9 MB 28.4 MB/s eta 0:00:03
#      ---------------------------- -------- 229.1/300.9 MB 29.8 MB/s eta 0:00:03
#      ---------------------------- -------- 231.1/300.9 MB 32.7 MB/s eta 0:00:03
#      ---------------------------- -------- 231.9/300.9 MB 34.4 MB/s eta 0:00:03
#      ---------------------------- -------- 233.1/300.9 MB 31.2 MB/s eta 0:00:03
#      ---------------------------- -------- 234.1/300.9 MB 31.2 MB/s eta 0:00:03
#      ----------------------------- ------- 235.9/300.9 MB 31.1 MB/s eta 0:00:03
#      ----------------------------- ------- 236.9/300.9 MB 34.6 MB/s eta 0:00:02
#      ----------------------------- ------- 238.2/300.9 MB 32.7 MB/s eta 0:00:02
#      ----------------------------- ------- 240.5/300.9 MB 34.4 MB/s eta 0:00:02
#      ----------------------------- ------- 241.5/300.9 MB 31.2 MB/s eta 0:00:02
#      ----------------------------- ------- 242.7/300.9 MB 32.7 MB/s eta 0:00:02
#      ------------------------------ ------ 244.3/300.9 MB 34.4 MB/s eta 0:00:02
#      ------------------------------ ------ 244.6/300.9 MB 34.4 MB/s eta 0:00:02
#      ------------------------------ ------ 246.9/300.9 MB 36.3 MB/s eta 0:00:02
7 MB/s eta 0:00:01
#      ----------- ---------------------------- 6.8/24.4 MB 48.4 MB/s eta 0:00:01
#      --------------- ------------------------ 9.2/24.4 MB 53.3 MB/s eta 0:00:01
#      ---------------- ---------------------- 10.5/24.4 MB 46.7 MB/s eta 0:00:01
#      -------------------- ------------------ 12.8/24.4 MB 46.9 MB/s eta 0:00:01
#      ----------------------- --------------- 14.9/24.4 MB 43.5 MB/s eta 0:00:01
#      -------------------------- ------------ 16.9/24.4 MB 46.7 MB/s eta 0:00:01
#      ----------------------------- --------- 18.5/24.4 MB 43.7 MB/s eta 0:00:01
#      ------------------------------ -------- 19.3/24.4 MB 43.5 MB/s eta 0:00:01
#      ------------------------------- ------- 19.9/24.4 MB 36.4 MB/s eta 0:00:01
#      ------------------------------------ -- 22.8/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.3/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      --------------------------------------  24.4/24.4 MB 40.9 MB/s eta 0:00:01
#      ---------------------------------------- 24.4/24.4 MB 9.3 MB/s eta 0:00:00
# Collecting grpcio<2.0,>=1.24.3
#   Downloading grpcio-1.59.2-cp310-cp310-win_amd64.whl (3.7 MB)
#      ---------------------------------------- 0.0/3.7 MB ? eta -:--:--
#      ------------------ --------------------- 1.7/3.7 MB 35.1 MB/s eta 0:00:01
#      ---------------------------------------  3.7/3.7 MB 46.9 MB/s eta 0:00:01
#      ---------------------------------------  3.7/3.7 MB 46.9 MB/s eta 0:00:01
#      ---------------------------------------- 3.7/3.7 MB 29.3 MB/s eta 0:00:00
# Requirement already satisfied: setuptools in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (67.8.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4.1)
# Collecting google-auth-oauthlib<2,>=0.5
#   Downloading google_auth_oauthlib-1.1.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.3)
# Collecting protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3
#   Downloading protobuf-4.23.4-cp310-abi3-win_amd64.whl (422 kB)
#      ---------------------------------------- 0.0/422.5 kB ? eta -:--:--
#      ------------------------------------- 422.5/422.5 kB 13.3 MB/s eta 0:00:00
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.29.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.23.4-py2.py3-none-any.whl (183 kB)
#      ---------------------------------------- 0.0/183.3 kB ? eta -:--:--
#      ------------------------------------- 183.3/183.3 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2023.7.22)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\amcco\anaconda3\envs\dev\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ---------------------------------------- 0.0/151.7 kB ? eta -:--:--
#      -------------------------------------- 151.7/151.7 kB 9.4 MB/s eta 0:00:00
# Installing collected packages: libclang, flatbuffers, termcolor, tensorflow-io-gcs-filesystem, tensorflow-estimator, tensorboard-data-server, rsa, protobuf, opt-einsum, oauthlib, ml-dtypes, keras, grpcio, google-pasta, gast, cachetools, astunparse, absl-py, requests-oauthlib, google-auth, google-auth-oauthlib, tensorboard, tensorflow-intel, tensorflow
# Successfully installed absl-py-2.0.0 astunparse-1.6.3 cachetools-5.3.2 flatbuffers-23.5.26 gast-0.5.4 google-auth-2.23.4 google-auth-oauthlib-1.1.0 google-pasta-0.2.0 grpcio-1.59.2 keras-2.15.0 libclang-16.0.6 ml-dtypes-0.2.0 oauthlib-3.2.2 opt-einsum-3.3.0 protobuf-4.23.4 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.15.1 tensorboard-data-server-0.7.2 tensorflow-2.15.0 tensorflow-estimator-2.15.0 tensorflow-intel-2.15.0 tensorflow-io-gcs-filesystem-0.31.0 termcolor-2.3.0

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd
application_df = pd.read_csv("https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv")
application_df.head()
# Out:
# WARNING:tensorflow:From C:\Users\amcco\anaconda3\envs\dev\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID column 'EIN'
application_df= application_df.drop(columns=["EIN"], axis=1)

# %%
# Determine the number of unique values in each column.
application_df.nunique()
# Out:
# NAME                      19568
# APPLICATION_TYPE             17
# AFFILIATION                   6
# CLASSIFICATION               71
# USE_CASE                      5
# ORGANIZATION                  4
# STATUS                        2
# INCOME_AMT                    9
# SPECIAL_CONSIDERATIONS        2
# ASK_AMT                    8747
# IS_SUCCESSFUL                 2
# dtype: int64

# %%
# Look at APPLICATION_TYPE value counts for binning
app_count = application_df['APPLICATION_TYPE'].value_counts()

app_count
# Out:
# T3     27037
# T4      1542
# T6      1216
# T5      1173
# T19     1065
# T8       737
# T7       725
# T10      528
# T9       156
# T13       66
# T12       27
# T2        16
# T25        3
# T14        3
# T29        2
# T15        2
# T17        1
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Choose a cutoff value and create a list of application types to be replaced
# use the variable name `application_types_to_replace`
application_types_to_replace= list(app_count[app_count< 528].index)

# Replace in dataframe
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app,"Other")

# Check to make sure binning was successful
application_df['APPLICATION_TYPE'].value_counts()
# Out:
# T3       27037
# T4        1542
# T6        1216
# T5        1173
# T19       1065
# T8         737
# T7         725
# T10        528
# Other      276
# Name: APPLICATION_TYPE, dtype: int64

# %%
# Look at CLASSIFICATION value counts for binning
classification_type = application_df["CLASSIFICATION"].value_counts()

# %%
# You may find it helpful to look at CLASSIFICATION value counts >1
classification_type = classification_type.loc[classification_type > 1]
classification_type.head()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# C3000     1918
# C2100     1883
# Name: CLASSIFICATION, dtype: int64

# %%
# Choose a cutoff value and create a list of classifications to be replaced
# use the variable name `classifications_to_replace`
classifications_to_replace = list(classification_type[classification_type < 1000].index)

# Replace in dataframe
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls,"Other")

# Check to make sure binning was successful
application_df['CLASSIFICATION'].value_counts()
# Out:
# C1000    17326
# C2000     6074
# C1200     4837
# Other     2235
# C3000     1918
# C2100     1883
# C1370        1
# C1236        1
# C2190        1
# C4200        1
# C5200        1
# C1248        1
# C2600        1
# C1580        1
# C6100        1
# C1820        1
# C1900        1
# C2570        1
# C1570        1
# C3700        1
# C2500        1
# C1283        1
# C2380        1
# C1732        1
# C1728        1
# C2170        1
# C4120        1
# C8210        1
# C4500        1
# C1245        1
# C2561        1
# C2150        1
# Name: CLASSIFICATION, dtype: int64

# %%
# Look at NAME value counts for binning
name_type = application_df["NAME"].value_counts()

# %%
# You may find it helpful to look at NAME value counts >1
name_type = name_type.loc[name_type > 1]
name_type.head()
# Out:
# PARENT BOOSTER USA INC                             1260
# TOPS CLUB INC                                       765
# UNITED STATES BOWLING CONGRESS INC                  700
# WASHINGTON STATE UNIVERSITY                         492
# AMATEUR ATHLETIC UNION OF THE UNITED STATES INC     408
# Name: NAME, dtype: int64

# %%
# Choose a cutoff value and create a list of names to be replaced
# use the variable name `names_to_replace`
names_to_replace = list(name_type[name_type < 100].index)

# Replace in dataframe
for nms in names_to_replace:
    application_df['NAME'] = application_df['NAME'].replace(nms,"Other")

# Check to make sure binning was successful
application_df['NAME'].value_counts()
# Out:
# Other                                             7211
# PARENT BOOSTER USA INC                            1260
# TOPS CLUB INC                                      765
# UNITED STATES BOWLING CONGRESS INC                 700
# WASHINGTON STATE UNIVERSITY                        492
#                                                   ...
# AIR FORCE ASSOICATION                                1
# SISKIYOU UPLAND TRAILS ASSOCIATION                   1
# MIRACLE OF GOD INTL CHURCH & MINISTRY ORG            1
# STROKE-APHASIA RECOVERY PROGRAM OF LUBBOCK INC       1
# WATERHOUSE CHARITABLE TR                             1
# Name: NAME, Length: 18807, dtype: int64

# %%
# Convert categorical data to numeric with `pd.get_dummies`
num_df = pd.get_dummies(application_df)

# %%
# Split our preprocessed data into our features and target arrays
y = num_df["IS_SUCCESSFUL"].values
X=num_df.drop(["IS_SUCCESSFUL"], axis =1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[14], line 3
#       1 # Split our preprocessed data into our features and target arrays
#       2 y = num_df["IS_SUCCESSFUL"].values
# ----> 3 X=num_df.drop(["IS_SUCCESSFUL"], axis =1).values
#       5 # Split the preprocessed data into a training and testing dataset
#       6 X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\frame.py:11739, in DataFrame.values(self)
#   11666 """
#   11667 Return a Numpy representation of the DataFrame.
#   11668
#    (...)
#   11736        ['monkey', nan, None]], dtype=object)
#   11737 """
#   11738 self._consolidate_inplace()
# > 11739 return self._mgr.as_array()
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\internals\managers.py:1770, in BlockManager.as_array(self, dtype, copy, na_value)
#    1768             arr = arr.astype(dtype, copy=False)
#    1769 else:
# -> 1770     arr = self._interleave(dtype=dtype, na_value=na_value)
#    1771     # The underlying data was copied within _interleave
#    1772     copy = False
#
# File ~\anaconda3\envs\dev\lib\site-packages\pandas\core\internals\managers.py:1809, in BlockManager._interleave(self, dtype, na_value)
#    1806 elif is_dtype_equal(dtype, str):
#    1807     dtype = np.dtype("object")
# -> 1809 result = np.empty(self.shape, dtype=dtype)
#    1811 itemmask = np.zeros(self.shape[0])
#    1813 if dtype == np.dtype("object") and na_value is lib.no_default:
#    1814     # much more performant than using to_numpy below
#
# MemoryError: Unable to allocate 4.82 GiB for an array with shape (18876, 34299) and data type int64

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# Compile, Train and Evaluate the Model

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer.
number_input_features= len(X_train[0])
hidden_nodes_layer1 =  10
hidden_nodes_layer2 = 8
hidden_nodes_layer3 = 6

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(
    tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu")
)

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="sigmoid"))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn.summary()

# %%
# Compile the model
nn.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the model
fit_model = nn.fit(X_train_scaled,y_train,epochs=100)

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn.evaluate(X_test_scaled,y_test,verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")

# %%
# Export our model to HDF5 file
nn.save('AlphabetSoupCharity_Optimization.h5')
